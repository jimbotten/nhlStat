# %%
import requests
import pandas as pd
import pprint
from datetime import date
import json
import glob

# %%
#dataGame = pd.json_normalize(d,record_path= ['rosterSpots'])
#dataGame.head(3)[['teamId','firstName.default']]
#dataGame[dataGame['teamId']==12][['firstName.default','lastName.default']]

# %%
df = pd.DataFrame()
for file in glob.glob('games/2023*.json'):
    #print(file)
    with open(f'{file}') as json_file:
        data = json.load(json_file)
    dataGame = pd.json_normalize(data,record_path= ['plays'])
    dataGame['game']=file
    df=pd.concat([df,dataGame])
# df.describe()
df.head(5)[['eventId','periodDescriptor.number','timeInPeriod','typeDescKey','details.winningPlayerId','details.xCoord','details.yCoord','details.shootingPlayerId','details.eventOwnerTeamId']]
# df.shape
players=pd.read_csv('games/players.csv')
players
# Out:
#      playerId  teamId  ...  firstName.default lastName.default
# 0     8470600      25  ...               Ryan            Suter
# 1     8470604       5  ...               Jeff           Carter
# 2     8470610      21  ...               Zach           Parise
# 3     8470613      12  ...              Brent            Burns
# 4     8470794      25  ...                Joe         Pavelski
# ..        ...     ...  ...                ...              ...
# 657   8484144      16  ...             Connor           Bedard
# 658   8484145       7  ...               Zach           Benson
# 659   8484293      12  ...              Yaniv           Perets
# 660   8484304      13  ...               Uvis        Balinskis
# 661   8484325      14  ...           Waltteri           Merela
#
# [662 rows x 6 columns]

# %%
df[(df['details.shootingPlayerId']==8480830)]
df.notna
# Out:
# <bound method DataFrame.notna of      eventId timeInPeriod  ... period details.servedByPlayerId
# 0       52.0        00:00  ...    NaN                      NaN
# 1       51.0        00:00  ...    NaN                      NaN
# 2      151.0        00:17  ...    NaN                      NaN
# 3      105.0        00:41  ...    NaN                      NaN
# 4      154.0        01:06  ...    NaN                      NaN
# ..       ...          ...  ...    ...                      ...
# 275    529.0        19:30  ...    3.0                      NaN
# 276    802.0        19:30  ...    3.0                      NaN
# 277   1023.0        19:55  ...    3.0                      NaN
# 278     50.0        20:00  ...    3.0                      NaN
# 279    604.0        20:00  ...    3.0                      NaN
#
# [15462 rows x 43 columns]>

# %% [markdown]
# ## types of records

# %%
df["typeDescKey"].unique()
#dataGame.dtypes
# Out:
# array(['period-start', 'faceoff', 'hit', 'blocked-shot', 'stoppage',
#        'shot-on-goal', 'delayed-penalty', 'penalty', 'giveaway',
#        'takeaway', 'missed-shot', 'goal', 'period-end', 'game-end',
#        'shootout-complete'], dtype=object)

# %% [markdown]
# ## Goals

# %%
goals=df[(df["typeDescKey"]=="missed-shot") | (df["typeDescKey"]=="blocked-shot")]
# grouped=goals.groupby('team.name')
goals.head(3)[['timeInPeriod','details.reason']]
#goals[['team.name','coordinates.x','coordinates.y']]
goals
# Out:
#      eventId timeInPeriod  ... period details.servedByPlayerId
# 3      105.0        00:41  ...    NaN                      NaN
# 6        8.0        01:16  ...    NaN                      NaN
# 12     122.0        01:45  ...    NaN                      NaN
# 28     218.0        05:46  ...    NaN                      NaN
# 35     228.0        06:58  ...    NaN                      NaN
# ..       ...          ...  ...    ...                      ...
# 244    932.0        11:11  ...    3.0                      NaN
# 245    935.0        11:20  ...    3.0                      NaN
# 254     49.0        14:02  ...    3.0                      NaN
# 258    974.0        15:25  ...    3.0                      NaN
# 277   1023.0        19:55  ...    3.0                      NaN
#
# [2988 rows x 43 columns]

# %%
goals=df[(df["typeDescKey"]=="goal") & (df["details.eventOwnerTeamId"]==12)][['timeInPeriod','periodDescriptor.number','details.xCoord','details.yCoord','details.shotType','details.scoringPlayerId','details.assist1PlayerId','details.eventOwnerTeamId','game']]
goals
# Out:
#     timeInPeriod  ...                   game
# 32         06:30  ...  games/2023021024.json
# 113        17:43  ...  games/2023021024.json
# 130        00:17  ...  games/2023021024.json
# 136        01:15  ...  games/2023021024.json
# 223        13:55  ...  games/2023021024.json
# ..           ...  ...                    ...
# 53         12:43  ...  games/2023020180.json
# 224        07:54  ...  games/2023020180.json
# 287        01:30  ...  games/2023020180.json
# 78         18:12  ...  games/2023020303.json
# 158        14:45  ...  games/2023020303.json
#
# [171 rows x 9 columns]

# %%
scores=goals.merge(players, how='left', left_on='details.scoringPlayerId', right_on='playerId')
# scores.describe
#df.groupby('team')['points'].mean()
grouped = scores.groupby(['playerId','firstName.default'])[['details.xCoord','details.yCoord']].mean()
scores['count']=scores['playerId'].value_counts()
scores
# Out:
#     timeInPeriod  periodDescriptor.number  ...  lastName.default  count
# 0          06:30                      1.0  ...         Martinook    NaN
# 1          17:43                      1.0  ...               Aho    NaN
# 2          00:17                      2.0  ...         Chatfield    NaN
# 3          01:15                      2.0  ...        Svechnikov    NaN
# 4          13:55                      2.0  ...             Burns    NaN
# ..           ...                      ...  ...               ...    ...
# 180        07:54                      3.0  ...             Skjei    NaN
# 181        01:30                      4.0  ...             Necas    NaN
# 182        18:12                      1.0  ...            Noesen    NaN
# 183        14:45                      2.0  ...           Bunting    NaN
# 184        14:45                      2.0  ...           Bunting    NaN
#
# [185 rows x 16 columns]

# %%
scores[(scores['playerId']==8480830)]
# Out:
#     timeInPeriod  periodDescriptor.number  ...  lastName.default  count
# 3          01:15                      2.0  ...        Svechnikov    NaN
# 8          16:15                      1.0  ...        Svechnikov    NaN
# 20         12:41                      3.0  ...        Svechnikov    NaN
# 40         01:21                      2.0  ...        Svechnikov    NaN
# 65         18:57                      3.0  ...        Svechnikov    NaN
# 112        19:29                      1.0  ...        Svechnikov    NaN
# 115        02:56                      3.0  ...        Svechnikov    NaN
# 152        10:46                      3.0  ...        Svechnikov    NaN
# 174        15:42                      3.0  ...        Svechnikov    NaN
# 177        18:49                      3.0  ...        Svechnikov    NaN
#
# [10 rows x 16 columns]
