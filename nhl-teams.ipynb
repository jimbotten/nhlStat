# %%
import requests
import pandas as pd
import pprint
from datetime import date
import json

# %%
#	/api/v1/game/2023020001/feed/live
gameRes=requests.get(f"https://statsapi.web.nhl.com/api/v1/teams/12?expand=team.stats").json()
json_formatted_str = json.dumps(gameRes, indent=2)
with open("team-stats.json", "w") as outfile:
  outfile.write(json_formatted_str)

#dataGame = pd.json_normalize(gameRes,record_path= ['liveData','plays','allPlays'])
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# /var/mobile/Containers/Data/Application/D98511FA-80DE-4C7B-A3E4-6DE3BB907A51/Documents/site-packages/urllib3/connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# /var/mobile/Containers/Data/Application/D98511FA-80DE-4C7B-A3E4-6DE3BB907A51/Documents/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      71
# ---> 72     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73         af, socktype, proto, canonname, sa = res
#
# ~/lib/python3.10/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     954     addrlist = []
# ...
