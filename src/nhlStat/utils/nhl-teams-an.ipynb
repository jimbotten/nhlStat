# %%
import requests
import pandas as pd
import pprint
from datetime import date
import json

# %%
#	/api/v1/game/2023020001/feed/live


with open('team-stats.json') as json_file:
    data = json.load(json_file)
#dataGame = pd.json_normalize(gameRes,record_path= ['liveData','plays','allPlays'])

# %%
dataGame["result.event"].unique()
# Out:
# array(['Game Scheduled', 'Period Ready', 'Period Start', 'Faceoff', 'Hit',
#        'Blocked Shot', 'Missed Shot', 'Penalty', 'Stoppage', 'Shot',
#        'Takeaway', 'Goal', 'Giveaway', 'Period End', 'Period Official',
#        'Game End', 'Game Official'], dtype=object)

# %%
dataGame.dtypes
# Out:
# result.event                  object
# result.eventCode              object
# result.eventTypeId            object
# result.description            object
# about.eventIdx                 int64
# about.eventId                  int64
# about.period                   int64
# about.periodType              object
# about.ordinalNum              object
# about.periodTime              object
# about.periodTimeRemaining     object
# about.dateTime                object
# about.goals.away               int64
# about.goals.home               int64
# players                       object
# coordinates.x                float64
# coordinates.y                float64
# team.id                      float64
# team.name                     object
# team.link                     object
# team.triCode                  object
# result.secondaryType          object
# result.strength.code          object
# result.strength.name          object
# result.gameWinningGoal        object
# result.emptyNet               object
# result.penaltySeverity        object
# result.penaltyMinutes        float64
# dtype: object

# %%
df=dataGame[dataGame["result.event"]=='Goal']
df[["team.name","team.triCode","result.description","about.ordinalNum","about.periodTime","result.strength.code","result.secondaryType"]]
#rslt_df = data[(data['teams.away.team.id'].isin(options)) |
# Out:
#                team.name team.triCode  \
# 20       Ottawa Senators          OTT
# 143  Carolina Hurricanes          CAR
# 223  Carolina Hurricanes          CAR
# 242  Carolina Hurricanes          CAR
# 275      Ottawa Senators          OTT
# 280      Ottawa Senators          OTT
# 294  Carolina Hurricanes          CAR
# 309  Carolina Hurricanes          CAR
#
#                                     result.description about.ordinalNum  \
# 20   Mathieu Joseph (1) Tip-In, assists: Artem Zub ...              1st
# 143  Michael Bunting (1) Wrist Shot, assists: Sebas...              2nd
# 223  Teuvo Teravainen (1) Snap Shot, assists: Marti...              2nd
# 242  Jordan Staal (1) Backhand, assists: Jordan Mar...              3rd
# 275  Parker Kelly (1) Wrist Shot, assists: Mathieu ...              3rd
# 280          Tim Stützle (1) Wrist Shot, assists: none              3rd
# 294  Brady Skjei (1) Slap Shot, assists: Jesper Fas...              3rd
# 309  Jaccob Slavin (1) Wrist Shot, assists: Jesperi...              3rd
#
#     about.periodTime result.strength.code result.secondaryType
# 20             03:14                 EVEN               Tip-In
# 143            02:55                  PPG           Wrist Shot
# 223            17:57                 EVEN            Snap Shot
# 242            00:20                 EVEN             Backhand
# 275            05:14                  SHG           Wrist Shot
# 280            05:49                 EVEN           Wrist Shot
# 294            07:51                 EVEN            Slap Shot
# 309            11:05                  SHG           Wrist Shot
